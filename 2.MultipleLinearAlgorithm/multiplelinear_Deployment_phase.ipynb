# %%
#Deployment
import pickle
loaded_model=pickle.load(open("multiplelinear_modulecreation.sav",'rb'))
result=loaded_model.predict([[12345,6543,64247,True,False]])
print(result)
# Out:
# [[54820.01207231]]
# C:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
