# %%
#we loading our model for the deployment phase means reading the model from our file
import pickle
loaded_model=pickle.load(open("final_empsalaryprediction_linear_regressionmodel.sav",'rb'))

# %%
#We prdicting the salary by providing the years of salary
result=loaded_model.predict([[13]])
print(result)
# Out:
# [[50069.16053019]]
# C:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#eventhough 0 years is not in dataset , we predicting using bias value.
result=loaded_model.predict([[0]])
print(result)
# Out:
# [[6996.75257732]]
# C:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
