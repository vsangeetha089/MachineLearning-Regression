# %%
import pickle
filename="Final_regressionAssignmentmodle.sav"
loaded_model=pickle.load(open(filename,'rb'))

# %%
age=float(input('Enter your age:'))
bmi=float(input('Enter your bmi:'))
children=int(input('Enter No of children:'))
sex=int(input('Enter your sex'))
smoking_habit=int(input('Confirm smoker or not:'))
# Out:
# Enter your age: 30
# Enter your bmi: 12
# Enter No of children: 3
# Enter your sex 1
# Confirm smoker or not: 1

# %%
result=loaded_model.predict([[age,bmi,children,sex,smoking_habit]])
result
# Out:
# array([130171.34529614])
