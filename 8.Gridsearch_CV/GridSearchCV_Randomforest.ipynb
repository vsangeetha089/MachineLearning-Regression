# %%
import pandas as pd

# %%
#datacollection
dataset=pd.read_csv("50_Startups.csv")
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
#data preprocessing
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0   165349.20       136897.80        471784.10  192261.83              0
# 1   162597.70       151377.59        443898.53  191792.06              0
# 2   153441.51       101145.55        407934.54  191050.39              1
# 3   144372.41       118671.85        383199.62  182901.99              0
# 4   142107.34        91391.77        366168.42  166187.94              1
# 5   131876.90        99814.71        362861.36  156991.12              0
# 6   134615.46       147198.87        127716.82  156122.51              0
# 7   130298.13       145530.06        323876.68  155752.60              1
# 8   120542.52       148718.95        311613.29  152211.77              0
# 9   123334.88       108679.17        304981.62  149759.96              0
# 10  101913.08       110594.11        229160.95  146121.95              1
# 11  100671.96        91790.61        249744.55  144259.40              0
# ...

# %%
dataset.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'Profit',
#        'State_Florida', 'State_New York'],
#       dtype='object')

# %%
#split input and output data
input_data=dataset[['R&D Spend', 'Administration', 'Marketing Spend','State_Florida', 'State_New York']]
output_data=dataset[['Profit']]
print(input_data)
print(output_data)
# Out:
#     R&D Spend  Administration  Marketing Spend  State_Florida  State_New York
# 0   165349.20       136897.80        471784.10              0               1
# 1   162597.70       151377.59        443898.53              0               0
# 2   153441.51       101145.55        407934.54              1               0
# 3   144372.41       118671.85        383199.62              0               1
# 4   142107.34        91391.77        366168.42              1               0
# 5   131876.90        99814.71        362861.36              0               1
# 6   134615.46       147198.87        127716.82              0               0
# 7   130298.13       145530.06        323876.68              1               0
# 8   120542.52       148718.95        311613.29              0               1
# 9   123334.88       108679.17        304981.62              0               0
# 10  101913.08       110594.11        229160.95              1               0
# ...

# %%
#split train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(input_data,output_data,test_size=0.30,random_state=0)
print(x_train)
print(y_train)
print(x_test)
print(y_test)
# Out:
#     R&D Spend  Administration  Marketing Spend  State_Florida  State_New York
# 7   130298.13       145530.06        323876.68              1               0
# 14  119943.24       156547.42        256512.92              1               0
# 45    1000.23       124153.04          1903.93              0               1
# 48     542.05        51743.15             0.00              0               1
# 29   65605.48       153032.06        107138.38              0               1
# 15  114523.61       122616.84        261776.23              0               1
# 30   61994.48       115641.28         91131.24              1               0
# 32   63408.86       129219.61         46085.25              0               0
# 16   78013.11       121597.55        264346.06              0               0
# 42   23640.93        96189.63        148001.11              0               0
# 20   76253.86       113867.30        298664.47              0               0
# ...

# %%
#module creation
#GridsearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
paramgrid={'criterion':['squared_error','absolute_error','poisson'],'n_estimators':[10,100]}
regressor_grid=GridSearchCV(RandomForestRegressor(),paramgrid,refit=True,verbose=3,n_jobs=-1)
regressor_grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# C:\anaconda3\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
results=regressor_grid.cv_results_
results
# Out:
# {'mean_fit_time': array([0.08040967, 0.54558854, 0.09564128, 0.59037147, 0.08024979,
#         0.34484949]),
#  'std_fit_time': array([0.00711732, 0.01448579, 0.02187626, 0.03252839, 0.00407625,
#         0.02713624]),
#  'mean_score_time': array([0.01453314, 0.04030399, 0.01353631, 0.02966933, 0.01657281,
#         0.01314545]),
#  'std_score_time': array([0.00426965, 0.00420334, 0.00172486, 0.00495982, 0.00323585,
#         0.00274003]),
#  'param_criterion': masked_array(data=['squared_error', 'squared_error', 'absolute_error',
#                     'absolute_error', 'poisson', 'poisson'],
#               mask=[False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'param_n_estimators': masked_array(data=[10, 100, 10, 100, 10, 100],
#               mask=[False, False, False, False, False, False],
#         fill_value=999999),
#  'params': [{'criterion': 'squared_error', 'n_estimators': 10},
# ...

# %%
table=pd.DataFrame.from_dict(results)
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.080410      0.007117         0.014533        0.004270
# 1       0.545589      0.014486         0.040304        0.004203
# 2       0.095641      0.021876         0.013536        0.001725
# 3       0.590371      0.032528         0.029669        0.004960
# 4       0.080250      0.004076         0.016573        0.003236
# 5       0.344849      0.027136         0.013145        0.002740
#
#   param_criterion  param_n_estimators  \
# 0   squared_error                  10
# 1   squared_error                 100
# 2  absolute_error                  10
# 3  absolute_error                 100
# 4         poisson                  10
# 5         poisson                 100
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'n_estimators':...           0.877981
# 1  {'criterion': 'squared_error', 'n_estimators':...           0.894141
# ...

# %%
y_predict=regressor_grid.predict(x_test)
print(y_predict)
print(y_test)
# Out:
# [103821.4548 133441.3173 135830.8598  82057.5962 183696.8084 115622.2584
#   68552.9013 100191.0844 117564.9041 167399.3056 101482.8209  89169.1928
#  116189.5505  90413.9601 128398.2593]
#        Profit
# 28  103282.38
# 11  144259.40
# 10  146121.95
# 41   77798.83
# 2   191050.39
# 27  105008.31
# 38   81229.06
# 31   97483.56
# 22  110352.25
# 4   166187.94
# 33   96778.92
# 35   96479.51
# 26  105733.54
# 34   96712.80
# 18  124266.90

# %%
#evaluation metrics
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_predict)
print('The best model',regressor_grid.best_params_)
print('The rscore',r_score)
# Out:
# The best model {'criterion': 'absolute_error', 'n_estimators': 100}
# The rscore 0.939826073964677
