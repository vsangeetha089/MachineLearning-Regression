# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
#split input and output data
input_data=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
print(input_data)
output_data=dataset[['charges']]
print(output_data)
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
#split train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(input_data,output_data,test_size=0.30,random_state=0)
print(x_train)
print(y_train)
print(x_test)
print(y_test)
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 1163   18  28.215         0         0           0
# 196    39  32.800         0         0           0
# 438    52  46.750         5         0           0
# 183    44  26.410         0         0           0
# 1298   33  27.455         2         1           0
# ...   ...     ...       ...       ...         ...
# 763    27  26.030         0         1           0
# 835    42  35.970         2         1           0
# 1216   40  25.080         0         1           0
# 559    19  35.530         0         1           0
# 684    33  18.500         1         0           0
#
# [936 rows x 5 columns]
#           charges
# 1163   2200.83085
# 196    5649.71500
# 438   12592.53450
# 183    7419.47790
# 1298   5261.46945
# ...           ...
# 763    3070.80870
# 835    7160.33030
# 1216   5415.66120
# 559    1646.42970
# 684    4766.02200
#
# [936 rows x 1 columns]
#       age     bmi  children  sex_male  smoker_yes
# ...

# %%
#Standardisation on both train and test dataset

from sklearn.preprocessing import StandardScaler
sc_input=StandardScaler()
x_train=sc_input.fit_transform(x_train)
x_test=sc_input.transform(x_test)

sc_output=StandardScaler()
y_train=sc_output.fit_transform(y_train)
y_test=sc_output.transform(y_test)

print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
# [[-1.5330973  -0.40713453 -0.89833872 -0.97676557 -0.50466988]
#  [-0.03364163  0.32855417 -0.89833872 -0.97676557 -0.50466988]
#  [ 0.89459283  2.56690911  3.25603402 -0.97676557 -0.50466988]
#  ...
#  [ 0.03776102 -0.91016269 -0.89833872  1.02378711 -0.50466988]
#  [-1.46169465  0.76659782 -0.89833872  1.02378711 -0.50466988]
#  [-0.46205754 -1.96596021 -0.06746417 -0.97676557 -0.50466988]]
# [[ 0.89459283 -0.08863026 -0.06746417  1.02378711 -0.50466988]
#  [ 0.53757957 -0.22180837 -0.06746417 -0.97676557 -0.50466988]
#  [ 0.60898222  1.57449152  0.76341038  1.02378711  1.98149332]
#  ...
#  [ 1.10880078  1.20785059 -0.89833872  1.02378711 -0.50466988]
#  [ 1.75142463  1.34905148 -0.06746417  1.02378711 -0.50466988]
#  [ 1.60861933 -0.92299913 -0.89833872 -0.97676557 -0.50466988]]
# [[-9.29114569e-01]
#  [-6.38651947e-01]
#  [-5.39325234e-02]
#  [-4.89603748e-01]
#  [-6.71349717e-01]
#  [-9.67549383e-01]
#  [ 1.99311860e+00]
#  [-7.49986519e-03]
#  [-5.43346082e-01]
# ...

# %%
age=float(input('Enter your age'))
bmi=float(input('Enter your bmi'))
child=float(input('Enter your child'))
sex=float(input('Enter your sex'))
smoke=float(input('Enter your smoke'))
# Out:
# Enter your age 34
# Enter your bmi 20
# Enter your child 1
# Enter your sex 1
# Enter your smoke 0

# %%
print('Before input standardisation')
user_input=[age,bmi,child,sex,smoke]
print(user_input)
print('After input standardisation')

user_input=sc_input.transform([[age,bmi,child,sex,smoke]])
user_input
# Out:
# Before input standardisation
# [34.0, 20.0, 1.0, 1.0, 0.0]
# After input standardisation
# C:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-0.39065489, -1.72527689, -0.06746417,  1.02378711, -0.50466988]])

# %%
loaded_module=pickle.load(open("finalpreprocessinputout_decisiontree_module.sav",'rb'))
result=loaded_module.predict(user_input)
print('Before Standardisation user output',result)
preoutput=sc_output.inverse_transform([result])
print('After Standardisation user output',preoutput)
# Out:
# Before Standardisation user output [0.09478444]
# After Standardisation user output [[14358.36437]]
